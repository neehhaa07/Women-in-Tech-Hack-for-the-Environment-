# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    'Combination': ['non-organic and disposable', 'organic and disposable', 
                    'reusable 1)', 'reusable 2)'],
    'France': [0.25, 0.25, 0.25, 0.25],
    'India': [0.75, 0.75, 0.75, 0.75],
    'US': [0.5, 0.5, 0.5, 0.5]
}

df = pd.DataFrame(data)

# %%
# Set the index to 'Combination'
df.set_index('Combination', inplace=True)

# Plot the graph
ax = df.plot(kind='bar', stacked=True, figsize=(10, 6))

# Customize the plot
plt.title('Combination Graph')
plt.xlabel('Combination')
plt.ylabel('Percentage')
plt.legend(title='Location')

# Show the plot
plt.show()

# %%
data = {
    'End of Life': ['disposable nonorganic tampons', 'disposable organic tampons',
                    'disposable nonorganic pads', 'disposable organic pads', 
                    'reusable pads', 'menstrual cups', 'menstrual underwear'],
    'France_toilets': [80, 80, 20, 20, 0, 0, 0],
    'France_incineration': [3, 3, 15, 15, 15, 15, 15],
    'France_landfill': [17, 17, 65, 65, 85, 85, 85],
    'India_toilets': [10, 10, 10, 10, 15, 15, 15],
    'India_incineration': [14, 14, 14, 14, 85, 85, 85],
    'India_landfill': [76, 76, 76, 76, 0, 0, 0],
    'US_toilets': [80, 80, 20, 20, 15, 15, 15],
    'US_incineration': [3, 3, 15, 15, 85, 85, 85],
    'US_landfill': [17, 17, 65, 65, 0, 0, 0]
}

df = pd.DataFrame(data)

# %%
# Set the index to 'End of Life'
df.set_index('End of Life', inplace=True)

# Plot the graph
ax = df.plot(kind='bar', stacked=True, figsize=(12, 6))

# Customize the plot
plt.title('End of Life Graph')
plt.xlabel('End of Life')
plt.ylabel('Percentage')
plt.legend(title='Location', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
data = {
    'Type': ['Menstrual pads', 'Tampons', 'Cloth menstrual pads', 'Menstrual cups', 'Menstrual underpants'],
    'Strengths': [3, 3, 4, 4, 4],
    'Weaknesses': [4, 4, 3, 5, 4],
    'Market Price (USD)': [0.2, 0.4, 10, 20, 20]
}

df = pd.DataFrame(data)

# %%
# Set the index to 'Type'
df.set_index('Type', inplace=True)

# Plot the graph
ax = df.plot(kind='bar', stacked=True, figsize=(10, 6))

# Customize the plot
plt.title('Strengths and Weaknesses of Menstrual Products')
plt.xlabel('Product Type')
plt.ylabel('Rating')
plt.legend(title='Criteria', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
data = {
    'Product Type': [
        'Menstrual pads', 'Menstrual pads',
        'Tampons', 'Tampons',
        'Cloth menstrual pads', 'Cloth menstrual pads',
        'Menstrual cups', 'Menstrual cups',
        'Menstrual underpants', 'Menstrual underpants'
    ],
    'Use Status': [
        'Never Used/Not Using', 'Used/Using',
        'Never Used/Not Using', 'Used/Using',
        'Never Used/Not Using', 'Used/Using',
        'Never Used/Not Using', 'Used/Using',
        'Never Used/Not Using', 'Used/Using'
    ],
    'Number of Subjects': [
        173, 267,
        270, 170,
        301, 139,
        225, 215,
        383, 57
    ],
    'Percentage': [
        39.3, 60.7,
        61.4, 38.6,
        68.4, 31.6,
        51.1, 48.9,
        87.0, 13.0
    ]
}

df = pd.DataFrame(data)

# %%
# Set the index to 'Product Type' and 'Use Status'
df.set_index(['Product Type', 'Use Status'], inplace=True)

# Unstack the dataframe to create grouped bars
df_unstacked = df.unstack(level='Use Status')

# Plot the graph
ax = df_unstacked.plot(kind='bar', figsize=(12, 6))

# Customize the plot
plt.title('Analysis of Consumers’ Use of Menstrual Products')
plt.xlabel('Product Type')
plt.ylabel('Number of Subjects / Percentage')
plt.legend(title='Use Status', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
data = {
    'Item': [
        'I attach importance to environmental protection and worry about nature being damaged.',
        'I give priority to environmental friendliness when buying goods.',
        'I prepare my own eco-friendly bags, chopsticks, and cups, and do not use disposable products, as possible.',
        'I am willing to buy eco-friendly products even at a high price.',
        'I reduce waste, and classify and recycle waste.',
        'I do not think it is eco-friendly to use menstrual tampons.',
        'I pay special attention to products with eco-friendly certificates when I shop.',
        'I learn about eco-friendly products online.',
        'I value ecological conservation and care about the survival rights of other species.',
        'I think environmental protection is more important than convenience.',
        'I support products that are more sustainable and eco-friendly.',
        'I always pay attention to issues related to environmental protection and sustainability.'
    ],
    'Strongly Disagree': [5, 2, 3, 3, 2, 8, 6, 4, 3, 3, 1, 2],
    'Disagree': [6, 15, 16, 20, 2, 31, 36, 9, 4, 21, 0, 4],
    'Fair': [46, 123, 88, 127, 34, 79, 187, 83, 83, 118, 26, 83],
    'Agree': [220, 213, 207, 226, 217, 178, 153, 218, 207, 203, 223, 220],
    'Strongly Agree': [163, 87, 126, 64, 185, 144, 58, 126, 143, 95, 190, 131]
}

df = pd.DataFrame(data)

# %%
# Set the index to 'Item'
df.set_index('Item', inplace=True)

# Plot the graph
ax = df.plot(kind='bar', stacked=True, figsize=(12, 6))

# Customize the plot
plt.title("Consumers' Cognition of Sustainability")
plt.xlabel('Item')
plt.ylabel('Number of Subjects')
plt.legend(title='Response', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
data = {
    'Item': [
        "I’m afraid of having my hymen broken.",
        "I think invasive menstrual products will break the hymen.",
        "I think the deep meaning of menstrual blood is dirtiness and filthiness.",
        "I think menstruation brings inconvenience in life.",
        "I do not think I should visit a temple during menstruation.",
        "I think it is inconvenient to exercise during menstruation.",
        "I feel ashamed and embarrassed about having menstruation.",
        "I think it’s shameful for people to see menstrual products, so I pack them in special bags.",
        "I usually refer to menstruation as “that thing”.",
        "I think menstruation is a normal physiological phenomenon of women.",
        "I support gender equality and do not subscribe to the traditional idea that men and women are different.",
        "I think menstruation is an important cycle of life reproduction and should be valued.",
        "Women should have the right to take menstrual leave from school or work.",
        "I tend to hide and keep silent regarding self-care during menstruation.",
        "I am afraid to touch my private parts directly."
    ],
    'Strongly Disagree': [219, 200, 324, 14, 240, 78, 266, 171, 85, 0, 2, 0, 0, 105, 211],
    'Disagree': [91, 104, 78, 22, 85, 99, 118, 139, 89, 0, 2, 1, 0, 152, 116],
    'Fair': [97, 78, 25, 78, 69, 119, 49, 96, 109, 7, 31, 32, 23, 127, 82],
    'Agree': [27, 52, 11, 217, 37, 119, 6, 30, 120, 99, 117, 139, 127, 48, 26],
    'Strongly Agree': [6, 6, 2, 109, 9, 25, 1, 4, 37, 334, 288, 268, 290, 8, 5]
}

df = pd.DataFrame(data)

# %%
# Set the index to 'Item'
df.set_index('Item', inplace=True)

# Plot the graph
ax = df.plot(kind='bar', stacked=True, figsize=(12, 6))

# Customize the plot
plt.title("Consumers' Cognition of Menstruation")
plt.xlabel('Item')
plt.ylabel('Number of Subjects')
plt.legend(title='Response', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
import pandas as pd

data = {
    'Construct of Analysis': [
        'Change of lifestyle in the context of universal sustainability',
        'Factors promoting green consumption',
        'Correlation between development of eco-friendly menstrual products and lifestyle',
        'Differences in the use of eco-friendly menstrual products between different groups',
        'Nature of eco-friendly menstrual products',
        'Current development of the menstrual product market in Taiwan',
        'Conditions for promotion of eco-friendly menstrual products'
    ],
    'Description': [
        'Policies in Taiwan that promote use habits, ...',
        'Sense of crisis and reflection that promote eco-friendly awareness, ...',
        'Society calls for eco-friendliness in addition to convenience and cleanliness, ...',
        'Differences in education and stratum, ...',
        'Disposable menstrual pads account for the majority, ...',
        'Attractive product design, Good sanitary education, ...',
        'More diversified products in the market, Better environment and facilities for using the products'
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                                Construct of Analysis  \
# 0  Change of lifestyle in the context of universa...
# 1                Factors promoting green consumption
# 2  Correlation between development of eco-friendl...
# 3  Differences in the use of eco-friendly menstru...
# 4          Nature of eco-friendly menstrual products
# 5  Current development of the menstrual product m...
# 6  Conditions for promotion of eco-friendly menst...
#
#                                          Description
# 0    Policies in Taiwan that promote use habits, ...
# 1  Sense of crisis and reflection that promote ec...
# 2  Society calls for eco-friendliness in addition...
# 3          Differences in education and stratum, ...
# 4  Disposable menstrual pads account for the majo...
# 5  Attractive product design, Good sanitary educa...
# 6  More diversified products in the market, Bette...
